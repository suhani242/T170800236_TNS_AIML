# %% [markdown]
# <a href="https://colab.research.google.com/github/suhani242/T170800236_TNS_AIML/blob/main/AIML_day7_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 10)
print (x)
y = np.sin(x)
print(y)
plt.plot(x, y, label="sin(x)", color="blue", linestyle="--")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Sine Wave Example")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# [ 0.          1.11111111  2.22222222  3.33333333  4.44444444  5.55555556
#   6.66666667  7.77777778  8.88888889 10.        ]
# [ 0.          0.8961922   0.79522006 -0.19056796 -0.96431712 -0.66510151
#   0.37415123  0.99709789  0.51060568 -0.54402111]

# %%
import numpy as np

y2 = np.cos(x)
print(y2)
plt.plot(x, y, label="sin(x)", color="red")
plt.plot(x, y2, label="cos(x)", color="green")
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Sine and Cosine Waves")
plt.legend()
plt.show()

# Example 2: Bar Chart
categories = ['A','B','C','D']
values = [10, 24, 36, 18]
plt.bar(categories, values, color=['blue','orange','green','red'], label="categories")
plt.xlabel("Categories")
plt.ylabel("Values")
plt.title("Bar Chart Example")
plt.legend ()
plt.show()

# Example 3: Histogram
#students = ['A','B','C','D']
data = np.random.randn(100)
print(data)
plt.hist(data, bins=100, color='purple', edgecolor='black',label="random")
plt.title("Histogram Example")
plt.legend()
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

#Example 3.1 Histogram (Students Marks)

marks = [10, 15, 25, 30, 35, 40, 45, 50, 52, 55, 60, 42, 48, 33, 28, 22, 18]

# Define bins (ranges)
bins = [0, 20, 40, 60]

# Create histogram
plt.hist(marks, bins=bins, edgecolor='black')

# Labels and title
plt.xlabel('Marks Range')
plt.ylabel('Number of Students')
plt.title('Histogram of Student Marks')

# Show plot
plt.show()

# Example 4: Scatter Plot
categories = ['A','B','C','D','E','F','G','H','I']
values = [10, 24, 36, 18,19,20,23,26,12]
plt.scatter(categories,values, color='darkgreen',label="categories")
plt.xlabel("Categories")
plt.ylabel("Values")
plt.title("Scatter Plot Example")
plt.legend()
plt.show()

# Example 5: Pie Chart
sizes = [60, 20, 25, 25, 50, 45, 23]
labels = ['Apple', 'Banana', 'Mango', 'Grapes', 'A', 'B', 'C']
plt.pie(sizes, labels=labels, autopct='%1.5f%%', startangle=90)
plt.title("Pie Chart Example")
plt.show()

# Example 6: Subplots
fig, axs = plt.subplots(2, 2, figsize=(8,8))

# Line Plot
axs[0,0].plot(x, y, color='blue')
axs[0,0].set_title("Line Plot")

# Bar Chart
axs[0,1].bar(categories, values, color='orange')
axs[0,1].set_title("Bar Chart")

# Histogram
axs[1,0].hist(marks, bins=bins, color='green')
axs[1,0].set_title("Histogram")

# Scatter Plot
axs[1,1].scatter(categories,values, color='red')
axs[1,1].set_title("Scatter Plot")

plt.tight_layout()
plt.show()
# Out:
# [ 1.          0.44366602 -0.60632092 -0.981674   -0.26474988  0.74675295
#   0.9273677   0.07613012 -0.859815   -0.83907153]
# [-0.40683572 -1.19767879 -1.39127667 -0.20491321 -0.66287246 -1.48701735
#  -1.15381241  0.73337498  0.23209611 -0.90338042  1.40712288 -1.32427397
#   1.57987646  1.70457912  0.27147182 -1.5789938   0.36954301  0.78143965
#   1.02059296  0.03607066 -0.09361579 -0.71523468  2.40864347  0.54774549
#   0.34849536  1.46706171 -0.63962404  1.15049619  0.87026575 -0.16280962
#   0.22478519 -0.82239747  0.33425729  1.64366227 -0.25894961 -1.13794602
#   0.76088637 -0.73706531 -0.10696706 -0.6939754   0.28023229  0.95031164
#  -0.52995754 -2.23153777  0.79458556  0.49863796 -1.76161009  0.00657599
#   0.25441988  0.3469242  -0.164598   -0.37601807 -0.16735623  0.25602064
#   0.06691222 -0.52852237  0.15900648 -0.29695064  0.77245035 -1.0262213
#  -0.55414523  0.49564178 -0.29062783 -0.62996049  0.33319937  1.03881097
#   0.68257278  0.58724652 -0.87638092 -0.62173311 -0.60534262 -1.25938787
#   0.08710765  0.71455808  1.89696786 -0.32461117  0.4279913   1.27769845
#   0.0842623  -2.24345432 -1.56717215 -1.43396536 -0.6656112  -0.22470696
#   0.92767534 -0.07770139 -0.2879693  -0.6005701   0.51173428 -1.63274073
#   0.31128216 -1.53176648 -0.19607404 -0.91555813 -0.97178158 -0.0154554
#  -1.24219896 -0.1796264  -0.59518299 -0.27462358]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

tips = sns.load_dataset("tips")

# 1. Scatter Plot
plt.figure(figsize=(6,4))
sns.scatterplot(x="total_bill", y="tip", data=tips, hue="sex", style="time")
plt.title("Scatter Plot - Total Bill vs Tip")
plt.show()

# 2. Line Plot
plt.figure(figsize=(6,4))
sns.lineplot(x="size", y="total_bill", data=tips, ci=None)
plt.title("Line Plot - Total Bill vs Size")
plt.show()

# 3. Bar Plot
plt.figure(figsize=(6,4))
sns.barplot(x="day", y="total_bill", data=tips, hue="sex")
plt.title("Bar Plot - Average Total Bill per Day")
plt.show()

# 4. Count Plot
plt.figure(figsize=(6,4))
sns.countplot(x="day", data=tips, hue="sex")
plt.title("Count Plot - Customers per Day")
plt.show()

# 5. Box Plot
plt.figure(figsize=(6,4))
sns.boxplot(x="day", y="total_bill", data=tips, hue="sex")
plt.title("Box Plot - Total Bill Distribution")
plt.show()

# 6. Violin Plot
plt.figure(figsize=(6,4))
sns.violinplot(x="day", y="total_bill", data=tips, hue="sex", split=True)
plt.title("Violin Plot - Distribution by Day and Gender")
plt.show()

# 7. Heatmap (Correlation Matrix)
plt.figure(figsize=(6,4))
corr = tips.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# 8. Pairplot
sns.pairplot(tips, hue="sex")
plt.suptitle("Pairplot of Tips Dataset")
plt.show()

# 9. Distribution Plot (Histogram + KDE)
plt.figure(figsize=(6,4))
sns.histplot(tips["total_bill"], kde=True, bins=20)
plt.title("Distribution of Total Bill")
plt.show()

# 10. Regression Plot
plt.figure(figsize=(6,4))
sns.regplot(x="total_bill", y="tip", data=tips)
plt.title("Regression Plot - Tip vs Total Bill")
plt.show()
# Out:
# /tmp/ipykernel_585/3005927433.py:18: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x="size", y="total_bill", data=tips, ci=None)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")

sns.lmplot(x="total_bill", y="tip", data=tips, hue="sex", aspect=1.5)
plt.title("Total Bill vs Tip with Regression Line")
plt.show()

# %%
sns.barplot(x="day", y="total_bill", hue="sex", data=tips)
plt.title("Average Total Bill per Day (Male vs Female)")
plt.show()

# %% [markdown]
# **1. Simple Scatter Plot**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

height = [150,160,170,180]
weight = [50,60,65,80]

sns.scatterplot(x=height, y=weight)

plt.show()

# %% [markdown]
# **2. Simple Boxplot**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

data = [10,12,15,18,20,25,30]

sns.boxplot(data=data)

plt.show()

# %% [markdown]
# **3. Barplot using Tips Dataset**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")

sns.barplot(x="day", y="total_bill", data=tips)

plt.show()

# %% [markdown]
# **4. Violinplot**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

students = ["A","A","A","B","B","B"]
marks = [70,80,90,60,75,85]

sns.violinplot(x=students, y=marks)

plt.show()

# %% [markdown]
# **Task :**
#
# Write a Python program using Seaborn to create a line plot for the following data.
#
# Days: 1, 2, 3, 4, 5
#
# Temperature: 30, 32, 31, 35, 36
