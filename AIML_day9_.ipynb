# %% [markdown]
# <a href="https://colab.research.google.com/github/suhani242/T170800236_TNS_AIML/blob/main/AIML_day9_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🧠 Introduction to Machine Learning
#
# Machine Learning (ML) is a subset of Artificial Intelligence (AI) that enables systems to learn from data and make predictions or decisions without being explicitly programmed.
#
# Instead of writing rules manually, we provide data and allow the model to learn patterns.
#
# ---
#
# ## 📌 Key Idea
#
# Traditional Programming:
# Input + Rules → Output
#
# Machine Learning:
# Input + Output → Model learns Rules
#
# ---
#
# ## ✅ Real-Life Examples
#
# - 📧 Spam Email Detection
# - 🎬 Netflix / YouTube Recommendations
# - 🏠 House Price Prediction
# - 💳 Fraud Detection
#
# ---
#
# ## 🎯 Why Machine Learning?
#
# - Handles large data efficiently
# - Improves automatically with experience
# - Finds hidden patterns humans may miss
#
# ---
#
# ## ⚠️ Important Note
#
# Machine Learning models are only as good as the data they are trained on.
# Bad data → Poor predictions

# %% [markdown]
# # 🔹 Types of Machine Learning
#
# Machine Learning is categorized based on **how the model learns from data**.
#
# ---
#
# ## 📊 Main Types of Machine Learning
#
# 1. Supervised Learning
# 2. Unsupervised Learning
# 3. Semi-Supervised Learning
# 4. Reinforcement Learning
#
# ---
# | Type            | Data      | Example                      |
# | --------------- | --------- | ---------------------------- |
# | Supervised      | Labeled   | Salary Prediction            |
# | Unsupervised    | Unlabeled | Customer Segmentation        |
# | Semi-Supervised | Mixed     | Medical Image Classification |
# | Reinforcement   | Rewards   | Self-driving Cars, Chess AI  |
# ---
#
# ## 🟢 1. Supervised Learning
#
# ### 📌 Definition:
# Model learns using **labeled data** (input + correct output).
#
# ### 🎯 Goal:
# Learn mapping → Input → Output
#
# ### ✅ Example:
# - Input: House Size → Output: Price
# - Input: Email → Output: Spam / Not Spam
#
# ### 🧠 Learns:
# Relationship between features and target
#
# ---
#
# ## 🔵 2. Unsupervised Learning
#
# ### 📌 Definition:
# Model learns from **unlabeled data** (no output given).
#
# ### 🎯 Goal:
# Find hidden patterns or structure
#
# ### ✅ Example:
# - Customer segmentation
# - Grouping similar products
#
# ### 🧠 Learns:
# Patterns, clusters, relationships
#
# ---
#
# ## 🟡 3. Semi-Supervised Learning
#
# ### 📌 Definition:
# Combination of **small labeled data + large unlabeled data**
#
# ### 🎯 Goal:
# Improve learning when labeled data is limited
#
# ### ✅ Example:
# - Few labeled images, many unlabeled images
# - Medical diagnosis with limited labeled cases
#
# ### 🧠 Learns:
# Uses labeled data to guide learning on unlabeled data
#
# ---
#
# ## 🟠 4. Reinforcement Learning
#
# ### 📌 Definition:
# Model learns by interacting with environment using **rewards and penalties**
#
# ### 🎯 Goal:
# Maximize reward over time
#
# ### ✅ Example:
# - Game playing (Chess, Ludo AI)
# - Self-driving cars
# - Robotics
#
# ### 🧠 Learns:
# Best actions through trial and error
#
# ---
#
# ## 🧠 Where Do Deep Learning & NLP Fit?
#
# ### 🔸 Deep Learning
# - Subset of Machine Learning
# - Uses Neural Networks with multiple layers
# - Can be applied in:
#   - Supervised Learning
#   - Unsupervised Learning
#   - Reinforcement Learning
#
# ---
#
# ### 🔸 Natural Language Processing (NLP)
# - Application area of ML
# - Focuses on understanding human language
#
# Examples:
# - Chatbots
# - Translation
# - Sentiment Analysis
#
# ---
#
# ## 📊 Quick Summary
#
# | Type | Data | Goal |
# |------|------|------|
# | Supervised | Labeled | Prediction |
# | Unsupervised | Unlabeled | Pattern Finding |
# | Semi-Supervised | Mixed | Better Learning |
# | Reinforcement | No dataset | Decision Making |

# %% [markdown]
# # ⚖️ How Are Types of Machine Learning Differentiated?
#
# The different types of Machine Learning are mainly distinguished based on:
# - The **kind of data available**
# - The **learning approach**
# - The **objective (goal)**
#
# ---
#
# ## 📌 1. Based on Data Availability
#
# - **Supervised Learning**
#   - Uses **labeled data**
#   - Each input has a correct output
#
# - **Unsupervised Learning**
#   - Uses **unlabeled data**
#   - No predefined output
#
# - **Semi-Supervised Learning**
#   - Uses **small labeled + large unlabeled data**
#
# - **Reinforcement Learning**
#   - No fixed dataset
#   - Learns from interaction with environment
#
# ---
#
# ## 📌 2. Based on Learning Approach
#
# - **Supervised Learning**
#   - Learns a mapping function: Input → Output
#
# - **Unsupervised Learning**
#   - Identifies hidden patterns, clusters, or structure
#
# - **Semi-Supervised Learning**
#   - Uses labeled data to guide learning on unlabeled data
#
# - **Reinforcement Learning**
#   - Learns via **trial and error** using rewards & penalties
#
# ---
#
# ## 📌 3. Based on Objective (Goal)
#
# - **Supervised Learning**
#   - Prediction (classification or regression)
#
# - **Unsupervised Learning**
#   - Pattern discovery (clustering, association)
#
# - **Semi-Supervised Learning**
#   - Improve performance with limited labeled data
#
# - **Reinforcement Learning**
#   - Learn optimal decision-making strategy
#
# ---
#
# ## 📊 Visual Intuition
#
# Supervised Learning:
# Input + Output → Learn → Predict Output
#
# Unsupervised Learning:
# Input Only → Find Patterns
#
# Reinforcement Learning:
# Agent → Action → Reward → Learn
#
# ---
#
# ## 🧠 Key Insight
#
# 👉 The **core difference** is:
# - What data is given
# - What feedback the model receives
# - What problem the model is trying to solve
#
# ---
#
# ## ⚠️ Common Confusion
#
# - Deep Learning is **NOT a separate type**, it is a **technique used across types**
# - NLP is **NOT a type**, it is an **application area**

# %% [markdown]
# # 🤖 Algorithms in Each Type of Machine Learning
#
# Each type of Machine Learning uses specific algorithms based on the problem it solves.
#
# ---
#
# ## 🟢 1. Supervised Learning Algorithms
#
# ### 📌 Used For:
# - Prediction (Regression)
# - Classification
#
# ### 🔢 Algorithms:
#
# #### 🔹 Regression Algorithms
# - Linear Regression
# - Polynomial Regression
#
# #### 🔹 Classification Algorithms
# - Logistic Regression
# - Decision Tree
# - Random Forest
# - Support Vector Machine (SVM)
# - K-Nearest Neighbors (KNN)
# - Naive Bayes
#
# ---
#
# ### ⚙️ How These Work (High-Level):
#
# - Learn relationship between input (X) and output (y)
# - Minimize error between predicted and actual values
# - Use labeled data to train
#
# ---
#
# ## 🔵 2. Unsupervised Learning Algorithms
#
# ### 📌 Used For:
# - Clustering
# - Pattern discovery
# - Dimensionality reduction
#
# ### 🔢 Algorithms:
#
# #### 🔹 Clustering
# - K-Means
# - Hierarchical Clustering
# - DBSCAN
#
# #### 🔹 Dimensionality Reduction
# - Principal Component Analysis (PCA)
# - t-SNE (advanced)
#
# ---
#
# ### ⚙️ How These Work:
#
# - No labels provided
# - Group similar data points
# - Reduce complexity while preserving patterns
#
# ---
#
# ## 🟡 3. Semi-Supervised Learning Algorithms
#
# ### 📌 Used For:
# - When labeled data is limited
#
# ### 🔢 Techniques / Algorithms:
#
# - Self-Training
# - Label Propagation
# - Label Spreading
# - Semi-Supervised SVM
#
# ---
#
# ### ⚙️ How These Work:
#
# - Train initial model on small labeled data
# - Predict labels for unlabeled data
# - Retrain using combined dataset
#
# ---
#
# ## 🟠 4. Reinforcement Learning Algorithms
#
# ### 📌 Used For:
# - Sequential decision making
#
# ### 🔢 Algorithms:
#
# - Q-Learning
# - SARSA
# - Deep Q Network (DQN)
# - Policy Gradient Methods
#
# ---
#
# ### ⚙️ How These Work:
#
# - Agent interacts with environment
# - Takes actions → receives rewards
# - Learns optimal strategy over time
#
# ---
#
# ## 🧠 Where Deep Learning Fits
#
# Deep Learning uses neural networks and can be applied in:
#
# - Supervised Learning → Image classification (CNN)
# - Unsupervised Learning → Autoencoders
# - Reinforcement Learning → Deep Q Networks
#
# ### 🔢 Deep Learning Models:
# - Artificial Neural Networks (ANN)
# - Convolutional Neural Networks (CNN)
# - Recurrent Neural Networks (RNN)
# - LSTM, GRU
# - Transformers
#
# ---
#
# ## 🗣️ Where NLP Fits
#
# NLP (Natural Language Processing) is an application area using ML & DL.
#
# ### 🔢 Common NLP Algorithms / Models:
# - TF-IDF
# - Word2Vec
# - GloVe
# - RNN / LSTM (for sequences)
# - Transformers (BERT, GPT)
#
# ---
#
# ## 📊 Summary Table
#
# | Type | Algorithms | Main Use |
# |------|-----------|----------|
# | Supervised | Regression, SVM, Trees | Prediction |
# | Unsupervised | K-Means, PCA | Pattern Finding |
# | Semi-Supervised | Label Propagation | Limited Labels |
# | Reinforcement | Q-Learning | Decision Making |

# %% [markdown]
# # 🤖 How Does an AI / ML Model Work?
#
# To understand Machine Learning deeply, you must know **how a model is trained and how it learns**.
#
# ---
#
# ## 📌 Complete ML Workflow
#
# 1. Data Collection
# 2. Data Preprocessing
# 3. Train-Test Split
# 4. Model Training
# 5. Prediction
# 6. Evaluation
# 7. Improvement
#
# ---
#
# ## 🧩 1. Data Collection
#
# Gather raw data from different sources:
# - CSV files
# - Databases
# - APIs
# - Sensors / Logs
#
# ### ✅ Example:
# House dataset → Size, Bedrooms, Price
#
# ---
#
# ## 🧹 2. Data Preprocessing
#
# Clean and prepare data before training.
#
# ### Steps:
# - Handle missing values
# - Remove duplicates
# - Encode categorical variables
# - Feature scaling (Normalization / Standardization)
#
# ---
#
# ## ✂️ 3. Train-Test Split
#
# Divide dataset into:
# - **Training Data** → Used to learn
# - **Testing Data** → Used to evaluate
#
# ### Typical Split:
# - 80% Training
# - 20% Testing
#
# ---
#
# ## 🧠 4. Model Training (Learning Phase)
#
# This is the **core step**.
#
# ### What Happens?
#
# - Model takes input features (X)
# - Compares prediction with actual output (y)
# - Adjusts internal parameters (weights)
#
# ---
#
# ## 🎯 Goal of Training
#
# Find a function:
#
# f(X) = y
#
# Example:
# - Input: House size
# - Output: Price
#
# ---
#
# ## 📉 5. Loss Function (Error Measurement)
#
# Loss function measures how wrong the prediction is.
#
# ### Examples:
# - Regression → Mean Squared Error (MSE)
# - Classification → Log Loss
#
# ### Goal:
# Minimize the loss
#
# ---
#
# ## ⚙️ 6. Optimization (Gradient Descent)
#
# Model improves by adjusting weights step-by-step.
#
# ### How?
#
# - Calculate error
# - Compute gradients
# - Update weights
#
# This process is repeated multiple times.
#
# ---
#
# ## 🔁 7. Epochs (Iterative Learning)
#
# - One **epoch** = One complete pass over training data
# - Model learns gradually over multiple epochs
#
# More epochs → Better learning (up to a limit)
#
# ---
#
# ## 🔮 8. Prediction
#
# After training:
#
# Model predicts output for new/unseen data.
#
# Example:
# - Input: New house size
# - Output: Predicted price
#
# ---
#
# ## 📊 9. Model Evaluation
#
# Check performance using metrics:
#
# ### Regression:
# - MSE, RMSE, R²
#
# ### Classification:
# - Accuracy
# - Precision
# - Recall
# - F1-score
#
# ---
#
# ## 🚀 10. Model Improvement
#
# Improve performance using:
# - Hyperparameter tuning
# - Better features
# - More data
# - Trying different algorithms
#
# ---
#
# ## 🔁 Full Learning Flow
#
# Data → Preprocessing → Training → Loss Calculation → Optimization → Prediction → Evaluation → Improvement
#
# ---
#
# ## 🧠 Key Intuition
#
# - Model **learns patterns**, not rules
# - Learning = **minimizing error**
# - Better data = Better model
#
# ---
#
# ## ⚠️ Important Note
#
# - Overfitting: Model memorizes training data
# - Underfitting: Model fails to learn patterns
#
# Goal → Balance both

# %% [markdown]
# # 📊 Model Evaluation in Machine Learning
#
# Model Evaluation is the process of measuring how well a trained model performs on unseen data.
#
# ---
#
# ## 📌 Why Evaluation is Important?
#
# - To check if the model is **accurate and reliable**
# - To compare different models
# - To detect **overfitting** and **underfitting**
#
# ---
#
# ## 🧪 Train vs Test Performance
#
# - **Training Accuracy** → Performance on training data
# - **Testing Accuracy** → Performance on unseen data
#
# ### ⚠️ Cases:
# - High Train + Low Test → Overfitting
# - Low Train + Low Test → Underfitting
# - Balanced → Good Model
#
# ---
#
# ## 🔢 1. Evaluation Metrics for Regression
#
# Used when output is **continuous (numbers)**
#
# ---
#
# ### 📉 Mean Squared Error (MSE)
#
# - Measures average squared error
# - Penalizes large errors more
#
# ### Formula:
# MSE = (1/n) * Σ (y_actual - y_predicted)²
#
# ---
#
# ### 📉 Root Mean Squared Error (RMSE)
#
# - Square root of MSE
# - Easier to interpret (same unit as output)
#
# ---
#
# ### 📈 R² Score (Coefficient of Determination)
#
# - Measures how well model explains variance
#
# ### Range:
# - 0 → Poor
# - 1 → Perfect
#
# ---
#
# ## 🔢 2. Evaluation Metrics for Classification
#
# Used when output is **categories (Yes/No, Spam/Not Spam)**
#
# ---
#
# ### 📊 Confusion Matrix
#
# |                | Predicted Positive | Predicted Negative |
# |----------------|------------------|------------------|
# | Actual Positive | True Positive (TP) | False Negative (FN) |
# | Actual Negative | False Positive (FP) | True Negative (TN) |
#
# ---
#
# ### 📌 Accuracy
#
# Accuracy = (TP + TN) / Total Predictions
#
# - Measures overall correctness
#
# ---
#
# ### 📌 Precision
#
# Precision = TP / (TP + FP)
#
# - How many predicted positives are actually correct
#
# ---
#
# ### 📌 Recall (Sensitivity)
#
# Recall = TP / (TP + FN)
#
# - How many actual positives are correctly identified
#
# ---
#
# ### 📌 F1 Score
#
# F1 = 2 × (Precision × Recall) / (Precision + Recall)
#
# - Balance between Precision and Recall
#
# ---
#
# ## 📊 When to Use What?
#
# - **Accuracy** → Balanced dataset
# - **Precision** → When false positives are costly
# - **Recall** → When false negatives are costly
# - **F1 Score** → When both matter
#
# ---
#
# ## 🔁 Cross Validation
#
# Instead of one split, use multiple splits for better evaluation.
#
# ### 📌 K-Fold Cross Validation:
# - Split data into K parts
# - Train on K-1 parts
# - Test on remaining part
# - Repeat K times
#
# ---
#
# ## 📉 Bias-Variance Tradeoff
#
# - **High Bias** → Underfitting
# - **High Variance** → Overfitting
#
# Goal → Find balance
#
# ---
#
# ## 🧠 Key Takeaways
#
# - Evaluation is done on **unseen data**
# - Different problems need different metrics
# - Always compare multiple models

# %% [markdown]
# # 🚀 End-to-End Machine Learning Pipeline (Part 1)
#
# This section covers the pipeline from **data collection to model saving**.
#
# ---
#
# # 🧭 Pipeline Overview (Part 1)
#
# Data Collection → Preprocessing → EDA → Feature Engineering → Model Development → Training → Evaluation → Model Saving
#
# ---
#
# # 📦 1. Data Collection
#
# Collect raw data from various sources.
#
# ## Sources:
# - CSV / Excel files
# - Databases (SQL / NoSQL)
# - APIs
# - Web scraping
# - Sensors / Logs
#
# ## Example:
# - E-commerce → user clicks, purchases
#
# ---
#
# # 🧹 2. Data Preprocessing
#
# Prepare clean data for modeling.
#
# ## Steps:
# - Handle missing values
# - Remove duplicates
# - Encode categorical variables
# - Feature scaling
#
# ---
#
# # 🔍 3. Exploratory Data Analysis (EDA)
#
# Understand the dataset.
#
# ## Goals:
# - Identify patterns
# - Detect outliers
# - Understand relationships
#
# ## Techniques:
# - Correlation matrix
# - Histograms
# - Boxplots
#
# ---
#
# # 🏗️ 4. Feature Engineering
#
# Create meaningful features.
#
# ## Techniques:
# - Feature creation
# - Encoding
# - Scaling
# - Feature selection
#
# ---
#
# # ✂️ 5. Train-Test Split
#
# Split dataset into:
# - Training Data
# - Testing Data
#
# ## Typical Split:
# - 80% Training
# - 20% Testing
#
# ---
#
# # 🤖 6. Model Development
#
# Choose algorithm based on problem type.
#
# ## Examples:
# - Regression → Linear Regression
# - Classification → Decision Tree, SVM
# - Clustering → K-Means
#
# ---
#
# # 🧠 7. Model Training
#
# Train model on training data.
#
# ## What happens:
# - Model learns patterns
# - Adjusts weights
# - Minimizes error
#
# ---
#
# # 📉 8. Loss Function
#
# Measures prediction error.
#
# ## Examples:
# - Regression → MSE
# - Classification → Log Loss
#
# ---
#
# # ⚙️ 9. Optimization
#
# Improve model performance.
#
# ## Method:
# - Gradient Descent
#
# ---
#
# # 🔁 10. Epochs
#
# - One full pass over data = 1 epoch
# - Multiple epochs improve learning
#
# ---
#
# # 🔮 11. Prediction
#
# Model predicts on unseen data.
#
# ---
#
# # 📊 12. Model Evaluation
#
# ## Regression:
# - MSE, RMSE, R²
#
# ## Classification:
# - Accuracy, Precision, Recall, F1
#
# ---
#
# # 🔧 13. Hyperparameter Tuning
#
# Improve performance.
#
# ## Techniques:
# - Grid Search
# - Random Search
#
# ---
#
# # 💾 14. Model Saving
#
# Save trained model for reuse.
#
# ```python
# import pickle
# pickle.dump(model, open('model.pkl', 'wb'))

# %% [markdown]
# # 🌐 15. Model Deployment
#
# After saving the model, the next step is to make it usable in real-world applications.
#
# ## What happens:
# - The trained model is exposed to external systems
# - Users or applications can send input and receive predictions
#
# ## Common Approach:
# - Deploy as an API (Application Programming Interface)
#
# ## Goal:
# Make the model accessible for real-time or batch predictions
#
# ---
#
# # 🔌 16. API Layer (Backend)
#
# The backend acts as a bridge between the model and the user interface.
#
# ## Responsibilities:
# - Accept user input
# - Send input to the model
# - Return predictions as response
#
# ## Goal:
# Enable communication between frontend and model
#
# ---
#
# # 🎨 17. Frontend Integration
#
# Create a user interface where users can interact with the model.
#
# ## Examples:
# - Web applications
# - Dashboards
# - Mobile apps
#
# ## Flow:
# User Input → Frontend → Backend/API → Model → Prediction → Display
#
# ## Goal:
# Make the system user-friendly and interactive
#
# ---
#
# # ☁️ 18. Deployment on Cloud
#
# Host the application online so it is accessible globally.
#
# ## Platforms:
# - Cloud services
# - Hosting platforms
#
# ## Goal:
# Ensure scalability and availability
#
# ---
#
# # 📡 19. Monitoring
#
# After deployment, continuously track model performance.
#
# ## Monitor:
# - Accuracy changes
# - Input data patterns
# - System performance
#
# ## Goal:
# Ensure model works correctly over time
#
# ---
#
# # 📉 20. Data Drift & Model Drift
#
# ## Data Drift:
# - Input data distribution changes over time
#
# ## Model Drift:
# - Model performance decreases due to changing data
#
# ## Goal:
# Detect when the model becomes outdated
#
# ---
#
# # 🔁 21. Retraining Pipeline
#
# Update the model using new data.
#
# ## Steps:
# - Collect new data
# - Retrain model
# - Evaluate again
# - Re-deploy
#
# ## Goal:
# Keep model accurate and relevant
#
# ---
#
# # 🔁 Real-World Flow
#
# User → Frontend → Backend API → Model → Prediction → Response → User
#
# ---
#
# # 🧠 Final Takeaway
#
# A Machine Learning system is not a one-time process.
#
# It is a **continuous cycle**:
# Build → Deploy → Monitor → Improve → Repeat
