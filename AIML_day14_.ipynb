# %% [markdown]
# <a href="https://colab.research.google.com/github/suhani242/T170800236_TNS_AIML/blob/main/AIML_day14_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
import matplotlib.pyplot as plt


iris = load_iris()
X = iris.data
y = iris.target.reshape(-1, 1)


encoder = OneHotEncoder(sparse_output=False)
y_encoded = encoder.fit_transform(y)


X_train, X_test, y_train, y_test = train_test_split(
    X, y_encoded, test_size=0.2, random_state=42
)


model = Sequential([
    Dense(10, input_shape=(X.shape[1],), activation='relu'),
    Dense(8, activation='relu'),
    Dense(y_encoded.shape[1], activation='softmax')
])


model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)


history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=50,
    batch_size=8,
    verbose=1
)


loss, accuracy = model.evaluate(X_test, y_test)
print(f"\nTest Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")


plt.figure(figsize=(10,5))
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Model Accuracy over Epochs')
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(10,5))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Model Loss over Epochs')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.0000e+00 - loss: 1.4878 - val_accuracy: 0.0000e+00 - val_loss: 1.3263
# Epoch 2/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0104 - loss: 1.3635 - val_accuracy: 0.0000e+00 - val_loss: 1.2809
# Epoch 3/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1458 - loss: 1.2945 - val_accuracy: 0.2083 - val_loss: 1.2688
# Epoch 4/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3438 - loss: 1.2451 - val_accuracy: 0.2917 - val_loss: 1.2508
# Epoch 5/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3438 - loss: 1.2076 - val_accuracy: 0.2917 - val_loss: 1.2290
# Epoch 6/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3438 - loss: 1.1683 - val_accuracy: 0.2917 - val_loss: 1.1818
# Epoch 7/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3438 - loss: 1.1287 - val_accuracy: 0.2917 - val_loss: 1.1429
# Epoch 8/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3646 - loss: 1.0909 - val_accuracy: 0.2917 - val_loss: 1.0998
# Epoch 9/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3646 - loss: 1.0526 - val_accuracy: 0.2917 - val_loss: 1.0669
# Epoch 10/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3854 - loss: 1.0129 - val_accuracy: 0.3333 - val_loss: 1.0001
# Epoch 11/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4479 - loss: 0.9742 - val_accuracy: 0.5000 - val_loss: 0.9561
# Epoch 12/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6667 - loss: 0.9367 - val_accuracy: 0.5417 - val_loss: 0.9246
# Epoch 13/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7812 - loss: 0.8977 - val_accuracy: 0.8333 - val_loss: 0.8781
# Epoch 14/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8958 - loss: 0.8639 - val_accuracy: 1.0000 - val_loss: 0.8318
# Epoch 15/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9375 - loss: 0.8279 - val_accuracy: 1.0000 - val_loss: 0.8042
# Epoch 16/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9271 - loss: 0.7928 - val_accuracy: 1.0000 - val_loss: 0.7685
# Epoch 17/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9167 - loss: 0.7604 - val_accuracy: 1.0000 - val_loss: 0.7433
# Epoch 18/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9375 - loss: 0.7286 - val_accuracy: 1.0000 - val_loss: 0.7170
# Epoch 19/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9479 - loss: 0.6992 - val_accuracy: 1.0000 - val_loss: 0.6879
# Epoch 20/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9583 - loss: 0.6718 - val_accuracy: 1.0000 - val_loss: 0.6577
# Epoch 21/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9479 - loss: 0.6474 - val_accuracy: 1.0000 - val_loss: 0.6484
# Epoch 22/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9375 - loss: 0.6188 - val_accuracy: 1.0000 - val_loss: 0.6111
# Epoch 23/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9479 - loss: 0.5953 - val_accuracy: 1.0000 - val_loss: 0.5974
# Epoch 24/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9583 - loss: 0.5706 - val_accuracy: 1.0000 - val_loss: 0.5742
# Epoch 25/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9688 - loss: 0.5506 - val_accuracy: 1.0000 - val_loss: 0.5515
# Epoch 26/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9792 - loss: 0.5306 - val_accuracy: 1.0000 - val_loss: 0.5397
# Epoch 27/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9583 - loss: 0.5104 - val_accuracy: 1.0000 - val_loss: 0.5207
# Epoch 28/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9583 - loss: 0.4930 - val_accuracy: 1.0000 - val_loss: 0.5082
# Epoch 29/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9583 - loss: 0.4752 - val_accuracy: 1.0000 - val_loss: 0.4822
# Epoch 30/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9583 - loss: 0.4604 - val_accuracy: 1.0000 - val_loss: 0.4779
# Epoch 31/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9583 - loss: 0.4456 - val_accuracy: 1.0000 - val_loss: 0.4636
# Epoch 32/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9583 - loss: 0.4312 - val_accuracy: 1.0000 - val_loss: 0.4490
# Epoch 33/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9583 - loss: 0.4217 - val_accuracy: 1.0000 - val_loss: 0.4234
# Epoch 34/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9688 - loss: 0.4070 - val_accuracy: 1.0000 - val_loss: 0.4246
# Epoch 35/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9583 - loss: 0.3955 - val_accuracy: 1.0000 - val_loss: 0.4134
# Epoch 36/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9583 - loss: 0.3849 - val_accuracy: 1.0000 - val_loss: 0.4069
# Epoch 37/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9583 - loss: 0.3768 - val_accuracy: 1.0000 - val_loss: 0.4041
# Epoch 38/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9583 - loss: 0.3661 - val_accuracy: 1.0000 - val_loss: 0.3774
# Epoch 39/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9688 - loss: 0.3586 - val_accuracy: 1.0000 - val_loss: 0.3685
# Epoch 40/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9583 - loss: 0.3507 - val_accuracy: 1.0000 - val_loss: 0.3712
# Epoch 41/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9583 - loss: 0.3409 - val_accuracy: 1.0000 - val_loss: 0.3523
# Epoch 42/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9583 - loss: 0.3365 - val_accuracy: 1.0000 - val_loss: 0.3414
# Epoch 43/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9688 - loss: 0.3278 - val_accuracy: 1.0000 - val_loss: 0.3371
# Epoch 44/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9583 - loss: 0.3204 - val_accuracy: 1.0000 - val_loss: 0.3360
# Epoch 45/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9688 - loss: 0.3137 - val_accuracy: 1.0000 - val_loss: 0.3212
# Epoch 46/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9688 - loss: 0.3091 - val_accuracy: 1.0000 - val_loss: 0.3252
# Epoch 47/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9583 - loss: 0.3009 - val_accuracy: 1.0000 - val_loss: 0.3061
# Epoch 48/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9792 - loss: 0.2963 - val_accuracy: 1.0000 - val_loss: 0.2957
# Epoch 49/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9583 - loss: 0.2922 - val_accuracy: 1.0000 - val_loss: 0.3042
# Epoch 50/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9792 - loss: 0.2858 - val_accuracy: 1.0000 - val_loss: 0.2789
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9667 - loss: 0.2971
#
# Test Loss: 0.2971
# Test Accuracy: 0.9667
