# %% [markdown]
# <a href="https://colab.research.google.com/github/suhani242/T170800236_TNS_AIML/blob/main/AIML_day6_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Sample dataset
data = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Age": [25, 30, 35],
    "Gender": ["Female", "Male", "Male"],
    "Salary": [50000, 60000, 70000],
    "Joining_Date": ["2022-01-01", "2021-06-15", "2020-03-20"]
}

df = pd.DataFrame(data)


df
# Out:
#       Name  Age  Gender  Salary Joining_Date
# 0    Alice   25  Female   50000   2022-01-01
# 1      Bob   30    Male   60000   2021-06-15
# 2  Charlie   35    Male   70000   2020-03-20

# %%
df.dtypes
# Out:
# Name            object
# Age              int64
# Gender          object
# Salary           int64
# Joining_Date    object
# dtype: object

# %%
import pandas as pd
import numpy as np
data =
    "Age": [18, 29, 30, 40, 60],
    "Salary": [20000, 30000, 50000, 80000, 150000]
}

df = pd.DataFrame(data)
df
# Out:
#    Age  Salary
# 0   18   20000
# 1   29   30000
# 2   30   50000
# 3   40   80000
# 4   60  150000

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

df_scaled = df.copy()
df_scaled[["Age", "Salary"]] = scaler.fit_transform(df[["Age", "Salary"]])

df_scaled
# Out:
#         Age    Salary
# 0 -1.230858 -0.984309
# 1 -0.452729 -0.770329
# 2 -0.381990 -0.342368
# 3  0.325399  0.299572
# 4  1.740179  1.797434

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

df_normalized = df.copy()
df_normalized[["Age", "Salary"]] = scaler.fit_transform(df[["Age", "Salary"]])

df_normalized
# Out:
#         Age    Salary
# 0  0.000000  0.000000
# 1  0.261905  0.076923
# 2  0.285714  0.230769
# 3  0.523810  0.461538
# 4  1.000000  1.000000

# %%
# Apply log transformation
df_log = df.copy()
df_log["Salary_Log"] = np.log(df_log["Salary"])

df_log
# Out:
#    Age  Salary  Salary_Log
# 0   18   20000    9.903488
# 1   29   30000   10.308953
# 2   30   50000   10.819778
# 3   40   80000   11.289782
# 4   60  150000   11.918391

# %%
# Create bins for Age
bins = [0, 20, 40, 100]
labels = ["Young", "Adult", "Senior"]

df["Age_Group"] = pd.cut(df["Age"], bins=bins, labels=labels)

df
# Out:
#    Age  Salary Age_Group
# 0   18   20000     Young
# 1   29   30000     Adult
# 2   30   50000     Adult
# 3   40   80000     Adult
# 4   60  150000    Senior

# %%
import pandas as pd

data = {
    "Name": ["A", "B", "C", "D", "E","F"],
    "Gender": ["Male", "Female", "Female", "Male", "B","Female"],
    "City": ["Mumbai", "Delhi", "Mumbai", "Pune", "Delhi","Delhi"],
    "Performance": ["Low", "Medium", "High", "Medium", "Low","High"]
}

df = pd.DataFrame(data)
df
# Out:
#   Name  Gender    City Performance
# 0    A    Male  Mumbai         Low
# 1    B  Female   Delhi      Medium
# 2    C  Female  Mumbai        High
# 3    D    Male    Pune      Medium
# 4    E       B   Delhi         Low
# 5    F  Female   Delhi        High

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df["Gender_Label"] = le.fit_transform(df["Gender"])
df["City_Label"] = le.fit_transform(df["City"])
df
# Out:
#   Name  Gender    City Performance  Gender_Label  City_Label
# 0    A    Male  Mumbai         Low             2           1
# 1    B  Female   Delhi      Medium             1           0
# 2    C  Female  Mumbai        High             1           1
# 3    D    Male    Pune      Medium             2           2
# 4    E       B   Delhi         Low             0           0
# 5    F  Female   Delhi        High             1           0

# %%
order = {"Low": 3, "Medium": 2, "High": 1}

df["Performance_Ordinal"] = df["Performance"].map(order)
df
# Out:
#   Name  Gender    City Performance  Gender_Label  City_Label  \
# 0    A    Male  Mumbai         Low             2           1
# 1    B  Female   Delhi      Medium             1           0
# 2    C  Female  Mumbai        High             1           1
# 3    D    Male    Pune      Medium             2           2
# 4    E       B   Delhi         Low             0           0
# 5    F  Female   Delhi        High             1           0
#
#    Performance_Ordinal
# 0                    3
# 1                    2
# 2                    1
# 3                    2
# 4                    3
# 5                    1

# %%
freq = df["City"].value_counts()

df["City_Freq"] = df["City"].map(freq)
df
# Out:
#   Name  Gender    City Performance  Gender_Label  City_Label  \
# 0    A    Male  Mumbai         Low             2           1
# 1    B  Female   Delhi      Medium             1           0
# 2    C  Female  Mumbai        High             1           1
# 3    D    Male    Pune      Medium             2           2
# 4    E       B   Delhi         Low             0           0
# 5    F  Female   Delhi        High             1           0
#
#    Performance_Ordinal  City_Freq
# 0                    3          2
# 1                    2          3
# 2                    1          2
# 3                    2          1
# 4                    3          3
# 5                    1          3

# %%
df["Target"] = [0, 1, 1, 0, 1,2]
target_mean = df.groupby("City")["Target"].mean()

df["City_Target_Encoded"] = df["City"].map(target_mean)
df
# Out:
#   Name  Gender    City Performance  Gender_Label  City_Label  \
# 0    A    Male  Mumbai         Low             2           1
# 1    B  Female   Delhi      Medium             1           0
# 2    C  Female  Mumbai        High             1           1
# 3    D    Male    Pune      Medium             2           2
# 4    E       B   Delhi         Low             0           0
# 5    F  Female   Delhi        High             1           0
#
#    Performance_Ordinal  City_Freq  Target  City_Target_Encoded
# 0                    3          2       0             0.500000
# 1                    2          3       1             1.333333
# 2                    1          2       1             0.500000
# 3                    2          1       0             0.000000
# 4                    3          3       1             1.333333
# 5                    1          3       2             1.333333

# %%
import pandas as pd

data = {
    "Name": ["A", "B", "C"],
    "Joining_Date": ["2022-01-15", "2021-06-20", "2020-12-05"]
}

df = pd.DataFrame(data)

df.info()
# Convert to datetime
df["Joining_Date"] = pd.to_datetime(df["Joining_Date"])

df

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          3 non-null      object
#  1   Joining_Date  3 non-null      object
# dtypes: object(2)
# memory usage: 180.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          3 non-null      object
#  1   Joining_Date  3 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), object(1)
# memory usage: 180.0+ bytes

# %%
df["Year"] = df["Joining_Date"].dt.year
df["Month"] = df["Joining_Date"].dt.month
df["Day"] = df["Joining_Date"].dt.day
df["dayname"] = df["Joining_Date"].dt.day_name()

df
# Out:
#   Name Joining_Date  Year  Month  Day   dayname
# 0    A   2022-01-15  2022      1   15  Saturday
# 1    B   2021-06-20  2021      6   20    Sunday
# 2    C   2020-12-05  2020     12    5  Saturday

# %%
import numpy as np
df["Month_sin"] = np.sin(2 * np.pi * df["Month"] / 12)
df["Month_cos"] = np.cos(2 * np.pi * df["Month"] / 12)

df
# Out:
#   Name Joining_Date  Year  Month  Day   dayname     Month_sin  Month_cos
# 0    A   2022-01-15  2022      1   15  Saturday  5.000000e-01   0.866025
# 1    B   2021-06-20  2021      6   20    Sunday  1.224647e-16  -1.000000
# 2    C   2020-12-05  2020     12    5  Saturday -2.449294e-16   1.000000

# %%
import matplotlib.pyplot as plt

plt.figure()

plt.plot(df["Month"], df["Month_sin"], marker='o', label="sin")
plt.plot(df["Month"], df["Month_cos"], marker='o', label="cos")

plt.xlabel("Month")
plt.ylabel("Value")
plt.title("Cyclical Encoding of Month")
plt.legend()
plt.grid()

plt.show()

# %%
import pandas as pd

data = {
    "Name": ["A", "B", "C"],
    "Price": [100, 200, 150],
    "Quantity": [2, 3, 5],
    "First_Name": ["John", "Jane", "Sam"],
    "Last_Name": ["Doe", "Smith", "Brown"],
    "Email": ["john@gmail.com", "jane@yahoo.com", "sam@outlook.com"]
}

df = pd.DataFrame(data)
df
# Out:
#   Name  Price  Quantity First_Name Last_Name            Email
# 0    A    100         2       John       Doe   john@gmail.com
# 1    B    200         3       Jane     Smith   jane@yahoo.com
# 2    C    150         5        Sam     Brown  sam@outlook.com

# %%
df["Total_Price"] = df["Price"] * df["Quantity"]

df
# Out:
#   Name  Price  Quantity First_Name Last_Name            Email  Total_Price
# 0    A    100         2       John       Doe   john@gmail.com          200
# 1    B    200         3       Jane     Smith   jane@yahoo.com          600
# 2    C    150         5        Sam     Brown  sam@outlook.com          750

# %%
df["Full_Name"] = df["First_Name"] + " " + df["Last_Name"]

df
# Out:
#   Name  Price  Quantity First_Name Last_Name            Email  Total_Price  \
# 0    A    100         2       John       Doe   john@gmail.com          200
# 1    B    200         3       Jane     Smith   jane@yahoo.com          600
# 2    C    150         5        Sam     Brown  sam@outlook.com          750
#
#     Full_Name
# 0    John Doe
# 1  Jane Smith
# 2   Sam Brown

# %%
df["Email_Domain"] = df["Email"].apply(lambda x: x.split("@")[1])

df
# Out:
#   Name  Price  Quantity First_Name Last_Name            Email  Total_Price  \
# 0    A    100         2       John       Doe   john@gmail.com          200
# 1    B    200         3       Jane     Smith   jane@yahoo.com          600
# 2    C    150         5        Sam     Brown  sam@outlook.com          750
#
#     Full_Name Email_Domain
# 0    John Doe    gmail.com
# 1  Jane Smith    yahoo.com
# 2   Sam Brown  outlook.com

# %%
df["Weight"] = [60, 70, 80]   # kg
df["Height"] = [1.6, 1.7, 1.8]  # meters

# BMI Formula
df["BMI"] = df["Weight"] / (df["Height"] ** 2)

df
# Out:
#   Name  Price  Quantity First_Name Last_Name            Email  Total_Price  \
# 0    A    100         2       John       Doe   john@gmail.com          200
# 1    B    200         3       Jane     Smith   jane@yahoo.com          600
# 2    C    150         5        Sam     Brown  sam@outlook.com          750
#
#     Full_Name Email_Domain  Weight  Height        BMI
# 0    John Doe    gmail.com      60     1.6  23.437500
# 1  Jane Smith    yahoo.com      70     1.7  24.221453
# 2   Sam Brown  outlook.com      80     1.8  24.691358

# %%
import pandas as pd
import numpy as np

data = {
    "Age": [25, np.nan, 30, 35, np.nan],
    "Salary": [50000, 60000, np.nan, 80000, 90000],
    "City": ["Mumbai", "Delhi", None, "Pune", "Delhi"]
}

df = pd.DataFrame(data)
df
# Out:
#     Age   Salary    City
# 0  25.0  50000.0  Mumbai
# 1   NaN  60000.0   Delhi
# 2  30.0      NaN    None
# 3  35.0  80000.0    Pune
# 4   NaN  90000.0   Delhi

# %%
df.isnull().sum()
# Out:
# Age       2
# Salary    1
# City      1
# dtype: int64

# %%
df2 = df.copy()
df2["Age"] = df2["Age"].fillna(df2["Age"].mean())

df2
# Out:
#     Age   Salary    City
# 0  25.0  50000.0  Mumbai
# 1  30.0  60000.0   Delhi
# 2  30.0      NaN    None
# 3  35.0  80000.0    Pune
# 4  30.0  90000.0   Delhi

# %%
df2 = df.copy()

df2["Salary"] = df2["Salary"].fillna(df2["Salary"].median())

df2
# Out:
#     Age   Salary    City
# 0  25.0  50000.0  Mumbai
# 1   NaN  60000.0   Delhi
# 2  30.0  70000.0    None
# 3  35.0  80000.0    Pune
# 4   NaN  90000.0   Delhi

# %%
df2 = df.copy()

df2["City"] = df2["City"].fillna(df2["City"].mode()[0])

df2
# Out:
#     Age   Salary    City
# 0  25.0  50000.0  Mumbai
# 1   NaN  60000.0   Delhi
# 2  30.0      NaN   Delhi
# 3  35.0  80000.0    Pune
# 4   NaN  90000.0   Delhi

# %%
df_ffill = df.ffill()

df_ffill
# Out:
#     Age   Salary    City
# 0  25.0  50000.0  Mumbai
# 1  25.0  60000.0   Delhi
# 2  30.0  60000.0   Delhi
# 3  35.0  80000.0    Pune
# 4  35.0  90000.0   Delhi

# %%
df_bfill = df.bfill()

df_bfill
# Out:
#     Age   Salary    City
# 0  25.0  50000.0  Mumbai
# 1  30.0  60000.0   Delhi
# 2  30.0  80000.0    Pune
# 3  35.0  80000.0    Pune
# 4   NaN  90000.0   Delhi

# %%
df["Age_missing"] = df["Age"].isnull().astype(int)

df
# Out:
#     Age   Salary    City  Age_missing
# 0  25.0  50000.0  Mumbai            0
# 1   NaN  60000.0   Delhi            1
# 2  30.0      NaN    None            0
# 3  35.0  80000.0    Pune            0
# 4   NaN  90000.0   Delhi            1

# %%
import pandas as pd

data = {
    "Age": [25, 30, 35, 40, 45],
    "Salary": [30000, 40000, 50000, 60000, 70000],
    "Experience": [1, 3, 5, 7, 9],
    "Purchased": [0, 0, 1, 1, 1]  # Target variable
}

df = pd.DataFrame(data)
df
# Out:
#    Age  Salary  Experience  Purchased
# 0   25   30000           1          0
# 1   30   40000           3          0
# 2   35   50000           5          1
# 3   40   60000           7          1
# 4   45   70000           9          1

# %%
df.corr()
# Out:
#                  Age    Salary  Experience  Purchased
# Age         1.000000  1.000000    1.000000   0.866025
# Salary      1.000000  1.000000    1.000000   0.866025
# Experience  1.000000  1.000000    1.000000   0.866025
# Purchased   0.866025  0.866025    0.866025   1.000000

# %%
corr_with_target = df.corr()["Purchased"]

corr_with_target
# Out:
# Age           0.866025
# Salary        0.866025
# Experience    0.866025
# Purchased     1.000000
# Name: Purchased, dtype: float64

# %%
df_selected = df.drop(columns=["Age"])

df_selected
# Out:
#    Salary  Experience  Purchased
# 0   30000           1          0
# 1   40000           3          0
# 2   50000           5          1
# 3   60000           7          1
# 4   70000           9          1

# %%
import pandas as pd

data = {
    "Salary": [30000, 35000, 40000, 45000, 50000, 1000000]  # Outlier present
}

df = pd.DataFrame(data)
df
# Out:
#     Salary
# 0    30000
# 1    35000
# 2    40000
# 3    45000
# 4    50000
# 5  1000000

# %%
Q1 = df["Salary"].quantile(0.25)
Q3 = df["Salary"].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

lower_bound, upper_bound

# Detect outliers
outliers = df[(df["Salary"] < lower_bound) | (df["Salary"] > upper_bound)]

print(outliers)
# Out:
#     Salary
# 5  1000000

# %%
df_no_outliers = df[(df["Salary"] >= lower_bound) & (df["Salary"] <= upper_bound)]
df_no_outliers
# Out:
#    Salary
# 0   30000
# 1   35000
# 2   40000
# 3   45000
# 4   50000

# %%
df_capped = df.copy()

df_capped["Salary"] = df_capped["Salary"].clip(lower_bound, upper_bound)
df_capped
# Out:
#    Salary
# 0   30000
# 1   35000
# 2   40000
# 3   45000
# 4   50000
# 5   67500

# %%
from scipy import stats

z_scores = stats.zscore(df["Salary"])
z_scores
# Out:
# array([-0.47508713, -0.46111398, -0.44714082, -0.43316767, -0.41919452,
#         2.23570412])

# %%
df_z = df[(abs(z_scores) > 2)]
df_z
# Out:
#     Salary
# 5  1000000
