# %% [markdown]
# <a href="https://colab.research.google.com/github/suhani242/T170800236_TNS_AIML/blob/main/AIML_day2_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Python Lists

# %%
my_list = [10, 20, 30, 40, 20,"Apple",True,1.5,"suhani"]
print("List:", my_list)
print (type(my_list))
# Out:
# List: [10, 20, 30, 40, 20, 'Apple', True, 1.5, 'suhani']
# <class 'list'>

# %%
numbers = [10, 20, 30]
numbers.append(25)
numbers.append(50)
print("After append:", numbers)
# Out:
# After append: [10, 20, 30, 25, 50]

# %%
numbers = [1, 2, 3]
print (numbers)
letter = ['A','B','C']
print(type(letter))
numbers.extend(letter)
print("After extend:", numbers)
print(type(numbers))
letter.extend(numbers)
print(letter)
# Out:
# [1, 2, 3]
# <class 'list'>
# After extend: [1, 2, 3, 'A', 'B', 'C']
# <class 'list'>
# ['A', 'B', 'C', 1, 2, 3, 'A', 'B', 'C']

# %%
# insert() → Inserts an element at a specified index
numbers = [1, 3, 4,5]
numbers.insert(3,"abcvghavdjav")
print("After insert:", numbers)
# Out:
# After insert: [1, 3, 4, 'abcvghavdjav', 5]

# %%
# remove() → Removes the first occurrence of a specified value
numbers = [1,2,5, 2,3,2,2, 3, 5,2,"apple"]
numbers.remove(5)
print("After remove:", numbers)
# Out:
# After remove: [1, 2, 2, 3, 2, 2, 3, 5, 2, 'apple']

# %%
# pop() → Removes and returns element at given index (default is last)
numbers = [10, 20, 30,40,50]
popped_value = numbers.pop(3)
print("Popped value:", popped_value)
print("After pop:", numbers)
# Out:
# Popped value: 40
# After pop: [10, 20, 30, 50]

# %%
numbers = [10, 20, 30]
numbers.clear()
print("After clear:", numbers)
# Out:
# After clear: []

# %%
# index() → Returns the index of the first occurrence of a specified value
numbers = [10,10,40, 30,20 ,20, 30, 40]
index_pos = numbers.index(40)
print("Index of :", index_pos)
# Out:
# Index of : 2

# %%
numbers = [1, 2, 3, 2, 4, 2,2,2,2,2,3,3,3]
count_numbers = numbers.count(2)
print("Count of value:", count_numbers)
# Out:
# Count of value: 7

# %%
numbers = [1, 2, 3, 4,"Kiran"]
numbers.reverse()
print("After reverse:", numbers)
# Out:
# After reverse: ['Kiran', 4, 3, 2, 1]

# %%
numbers = ['c' , 'a' , 'z']
numbers.sort()
print("After sort:", numbers)
# Out:
# After sort: ['a', 'c', 'z']

# %%
numbers = [1, 2, 3,"kartik"]
copy_numbers = numbers.copy()
print("Copied list:", copy_numbers)
# Out:
# Copied list: [1, 2, 3, 'kartik']

# %%
numbers = [1, 2, 3, 4,5,6,7,6]
result = len (numbers)
print("Length of list:", result)
# Out:
# Length of list: 8

# %%
numbers = [1, 2, 3, 4,5,6.6]
total = sum(numbers)
print("Sum of list:", total)
# Out:
# Sum of list: 21.6

# %%
numbers = [5, 8, 2, 10, 3,140,-9]
print("Max value:", max(numbers))
print("Min value:", min(numbers))
# Out:
# Max value: 140
# Min value: -9
